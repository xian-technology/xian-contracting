# %% [markdown]
# # A very simple Counter contract
#
# Let's start by writing a simple Xian contract that stores a number everyone can increment:

# %%
counter_contract = """
count = Variable()

@construct
def constructor():
    count.set(0)

@export
def increment():
    count.set(count.get() + 1)
"""

# %% [markdown]
# To interact with smart contracts we need a client:

# %%
from contracting.client import ContractingClient

client = ContractingClient(signer="ren")
client.flush()

# %% [markdown]
# Next we will submit the contract to the client:

# %%
client.submit(counter_contract, name="con_counter")

# %% [markdown]
# Now we can get the submitted contract to interact with it:

# %%
contract = client.get_contract("con_counter")

# %% [markdown]
# Let's investigate the counter:

# %%
contract.count.get()

# %% [markdown]
# It is 0 as expected because we initialized it to 0 in the constructor function.
#
# Everyone can increment the counter by calling the public increment function:

# %%
contract.increment()

# %% [markdown]
# Let's investigate the counter again:

# %%
contract.count.get()

# %% [markdown]
# Seems like our increment function works.
#
# This concludes our first look at writing smart contracts in Python on Xian. Dive deeper with the next example.
